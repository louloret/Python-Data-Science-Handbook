# %%
def donothing(x):
    return x

# %%
# %paste 
def donothing(x):
    return x
# Out:
# ERROR:root:Line magic function `%paste` not found.

# %%
# file: untitled7.py

def square(x):
    """square a number"""
    return x ** 2

for N in range(1, 4):
    print(N, "squared is", square(N))
# Out:
# 1 squared is 1
# 2 squared is 4
# 3 squared is 9

# %%
#remember to move downloaded script to C:\Users\Luis
# %run untitled7.py
# Out:
# 1 squared is 1
# 2 squared is 4
# 3 squared is 9

# %%
# %timeit L = [n ** 2 for n in range(1000)]
# Out:
# 1000 loops, best of 3: 370 µs per loop

# %%
#second % sign can manage multiple lines of output
# %%timeit
L = []
for n in range(1000):
    L.append(n ** 2)
# Out:
#   File "<ipython-input-16-29a89d6b53ed>", line 2
#     %%timeit
#     ^
# SyntaxError: invalid syntax

# %%
L
# Out:
# [0,
#  1,
#  4,
#  9,
#  16,
#  25,
#  36,
#  49,
#  64,
#  81,
#  100,
#  121,
#  144,
#  169,
#  196,
#  225,
#  256,
#  289,
#  324,
#  361,
#  400,
#  441,
#  484,
#  529,
#  576,
#  625,
#  676,
#  729,
#  784,
#  841,
#  900,
#  961,
#  1024,
#  1089,
#  1156,
#  1225,
#  1296,
#  1369,
#  1444,
#  1521,
#  1600,
#  1681,
#  1764,
#  1849,
#  1936,
#  2025,
#  2116,
#  2209,
#  2304,
#  2401,
#  2500,
#  2601,
#  2704,
#  2809,
#  2916,
#  3025,
#  3136,
#  3249,
#  3364,
#  3481,
#  3600,
#  3721,
#  3844,
#  3969,
#  4096,
#  4225,
#  4356,
#  4489,
#  4624,
#  4761,
#  4900,
#  5041,
#  5184,
#  5329,
#  5476,
#  5625,
#  5776,
#  5929,
#  6084,
#  6241,
#  6400,
#  6561,
#  6724,
#  6889,
#  7056,
#  7225,
#  7396,
#  7569,
#  7744,
#  7921,
#  8100,
#  8281,
#  8464,
#  8649,
#  8836,
#  9025,
#  9216,
#  9409,
#  9604,
#  9801,
#  10000,
#  10201,
#  10404,
#  10609,
#  10816,
#  11025,
#  11236,
#  11449,
#  11664,
#  11881,
#  12100,
#  12321,
#  12544,
#  12769,
# ...

# %%
# Out:
# UsageError: %%timeit is a cell magic, but the cell body is empty. Did you mean the line magic %timeit (single %)?

# %%
import math

# %%
math.sin(2)
# Out:
# 0.9092974268256817

# %%
math.cos(2)
# Out:
# -0.4161468365471424

# %%
print(In)
# Out:
# ['', 'def donothing(x)\n    return x', "get_ipython().magic('paste')\ndef donothing(x)\n    return x", 'def donothing(x):\n    return x', "get_ipython().magic('paste')\ndef donothing(x):\n    return x", '# file: myscript.py\n\ndef square(x):\n    """square a number"""\n    return x ** 2\n\nfor N in range(1, 4):\n    print(N, "squared is", square(N))', "get_ipython().magic('run untitled7.py')", "get_ipython().magic('run untitled7.py')", "get_ipython().magic('timeit L = [n ** 2 for n in range(1000)]')", "get_ipython().run_cell_magic('timeit', '', '    L = []\\n    for n in range(1000):\\n    L.append(n ** 2)')", "get_ipython().run_cell_magic('timeit', '', 'L = []\\nfor n in range(1000):\\nL.append(n ** 2)')", 'L = []\nfor n in range(1000):\nL.append(n ** 2)', 'L = []\nfor n in range(1000):\n    L.append(n ** 2)', 'L', "get_ipython().run_cell_magic('timeit', '', '')", '#second % sign can manage multiple lines of output\n%%timeit\nL = []\nfor n in range(1000):\n    L.append(n ** 2)', '#s
# ...

# %%
Out
# Out:
# {13: [0,
#   1,
#   4,
#   9,
#   16,
#   25,
#   36,
#   49,
#   64,
#   81,
#   100,
#   121,
#   144,
#   169,
#   196,
#   225,
#   256,
#   289,
#   324,
#   361,
#   400,
#   441,
#   484,
#   529,
#   576,
#   625,
#   676,
#   729,
#   784,
#   841,
#   900,
#   961,
#   1024,
#   1089,
#   1156,
#   1225,
#   1296,
#   1369,
#   1444,
#   1521,
#   1600,
#   1681,
#   1764,
#   1849,
#   1936,
#   2025,
#   2116,
#   2209,
#   2304,
#   2401,
#   2500,
#   2601,
#   2704,
#   2809,
#   2916,
#   3025,
#   3136,
#   3249,
#   3364,
#   3481,
#   3600,
#   3721,
#   3844,
#   3969,
#   4096,
#   4225,
#   4356,
#   4489,
#   4624,
#   4761,
#   4900,
#   5041,
#   5184,
#   5329,
#   5476,
#   5625,
#   5776,
#   5929,
#   6084,
#   6241,
#   6400,
#   6561,
#   6724,
#   6889,
#   7056,
#   7225,
#   7396,
#   7569,
#   7744,
#   7921,
#   8100,
#   8281,
#   8464,
#   8649,
#   8836,
#   9025,
#   9216,
#   9409,
#   9604,
#   9801,
#   10000,
#   10201,
#   10404,
# ...

# %%
#In object is a list, which keeps track of the commands in order
print(In[1])
# Out:
# def donothing(x)
#     return x

# %%
#Out object is not a list but a dictionary mapping 
#input numbers to their outputs (if any)
print(Out[19])
# Out:
# -0.4161468365471424

# %%
#keep in mind print does not return an output

# %%
Out[18]+ Out[19]
# Out:
# 0.4931505902785393

# %%
print(_)
# Out:
# 0.4931505902785393

# %%
#suppress output by adding semi colon at the end
math.sin(2) + math.cos(2)
# Out:
# 0.4931505902785393

# %%
#Profiling Full Scripts: %prun
def sum_of_lists(N):
    total = 0
    for i in range(5):
        L = [j ^ (j >> i) for j in range(N)]
        total += sum(L)
    return total

# %prun sum_of_lists(1000000)

# %%
#line by Line profiling
import sys
# !conda install --yes --prefix {sys.prefix} line_profiler
# Out:
# Fetching package metadata .............
# Solving package specifications: .
#
# Package plan for installation in environment C:\Users\Luis\Anaconda3:
#
# The following packages will be UPDATED:
#
#     conda:     4.3.30-py35hec795fb_0 --> 4.4.8-py35_0
#     conda-env: 2.6.0-0               --> 2.6.0-h36134e3_1
#     pycosat:   0.6.1-py35_1          --> 0.6.3-py35h456c199_0
#
# conda-env-2.6.   0% |                              | ETA:  --:--:--   0.00  B/s
# conda-env-2.6. 100% |###############################| ETA:  0:00:00 897.61 kB/s
# conda-env-2.6. 100% |###############################| Time: 0:00:00 117.05 kB/s
#
# pycosat-0.6.3-   0% |                              | ETA:  --:--:--   0.00  B/s
# pycosat-0.6.3-  15% |####                           | Time: 0:00:00 511.63 kB/s
# pycosat-0.6.3-  31% |#########                      | Time: 0:00:00 642.00 kB/s
# pycosat-0.6.3-  47% |##############                 | Time: 0:00:00 817.32 kB/s
# ...

# %%
#Memory profiling
# !conda install --yes --prefix {sys.prefix} memory_profiler
# Out:
# ^C

# %%
sys.path
# Out:
# ['',
#  'C:\\Users\\Luis\\Anaconda3\\python35.zip',
#  'C:\\Users\\Luis\\Anaconda3\\DLLs',
#  'C:\\Users\\Luis\\Anaconda3\\lib',
#  'C:\\Users\\Luis\\Anaconda3',
#  'C:\\Users\\Luis\\Anaconda3\\lib\\site-packages',
#  'C:\\Users\\Luis\\Anaconda3\\lib\\site-packages\\Sphinx-1.4.6-py3.5.egg',
#  'C:\\Users\\Luis\\Anaconda3\\lib\\site-packages\\win32',
#  'C:\\Users\\Luis\\Anaconda3\\lib\\site-packages\\win32\\lib',
#  'C:\\Users\\Luis\\Anaconda3\\lib\\site-packages\\Pythonwin',
#  'C:\\Users\\Luis\\Anaconda3\\lib\\site-packages\\setuptools-27.2.0-py3.5.egg',
#  'C:\\Users\\Luis\\Anaconda3\\lib\\site-packages\\IPython\\extensions',
#  'C:\\Users\\Luis\\.ipython']

# %%
print("Hello")
# Out:
# Hello

# %%
# !jupyter kernelspec list
# Out:
# Available kernels:
#   python3    C:\Users\Luis\Anaconda3\lib\site-packages\ipykernel\resources

# %%
# !type python
# Out:
# The system cannot find the file specified.

# %%
sys.executable
# Out:
# 'C:\\Users\\Luis\\Anaconda3\\python.exe'

# %%
# !echo $SHELL
# Out:
# $SHELL

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-72-2a2876207f42> in <module>()
# ----> 1 np.random.seed(0)
#
# NameError: name 'np' is not defined
